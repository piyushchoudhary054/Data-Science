# %%
#EDA -> Exploratory Data Analysis

# %% [markdown]
# Parts of EDA
#
# 1. Univariate Analysis == > Analysis on a single Independent column
# 2. Bivariate Analysis == > Analysis on two columns
# 3. Multivariate Analysis == > Analysis on more than 2 columns

# %% [markdown]
# # Data Types
#  1. Numerical Data == > Continuous Data == > Age(year ,month , days) , Height ,
#  2. Categorical Data == > Descrete Data == > Total Number of Employees , Marital

# %%
import pandas as pd 
import matplotlib.pyplot as plt   # viusaliztion library
import seaborn as sns               # matplotlib updated verson

df = pd.read_csv(r'C:\Users\PIYUSH\Downloads\Datasets\titanic - titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %% [markdown]
# # Univariate Analysis

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
sns.countplot(x = df['Survived'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# if we want to see actual values  then we can use value_counts()

df['Survived'].value_counts()
# Out:
# Survived
# 0    266
# 1    152
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
df['Survived'].value_counts().plot(kind='pie',autopct='%.2f')  # autopct-> autopercenage
# Out:
# <Axes: >

# %%
# If We have Numerical data then we use Histogram
# because it finds the distribution .

# %%
plt.hist(x=df['Age'])
plt.show()

# %%
# 2 . Distplot
# curve == > KDE(Kernal Density Extraction)
# use for find Probabilty

# sns.histplot(x= df['Age'])

# sns.distplot(x = df['Age'] , hist = False)

# 3. Boxplot
# for find our outliers

# 1. Lower fence
# 2.25% data
# 3. IQR(Inter Quartile Range) (75%-25%)
# 4  75% data
#5 upper fence

# %%
# x = 1,2,3,4,5
# mean = (1+2+3+4+5)/5 = 15/5 = 3
# x = 1,2,3,4,5,100
# mean = 15+100/6 = 115/6 = 19.3

### HERE 100 IS OUTLIER .

# %%
sns.boxplot(x=df['Age'])
# Out:
# <Axes: xlabel='Age'>
