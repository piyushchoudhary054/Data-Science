# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\PIYUSH\Downloads\Datasets\placement - placement.csv')

# %%
df
# Out:
#     cgpa  resume_score  placed
# 0   8.14          6.52       1
# 1   6.17          5.17       0
# 2   8.27          8.86       1
# 3   6.88          7.27       1
# 4   7.52          7.30       1
# ..   ...           ...     ...
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0
#
# [100 rows x 3 columns]

# %%
df.isnull().sum()
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.sample()
# Out:
#     cgpa  resume_score  placed
# 63  8.65          7.58       1

# %%
df.iloc[0:4,[0,1,2]]
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1

# %%
df.loc[0:4,['cgpa','resume_score','placed']]
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.tail()
# Out:
#     cgpa  resume_score  placed
# 95  6.33          6.38       0
# 96  8.23          7.76       1
# 97  6.65          7.78       0
# 98  8.14          5.63       1
# 99  6.09          6.61       0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   cgpa          100 non-null    float64
#  1   resume_score  100 non-null    float64
#  2   placed        100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df.describe()
# Out:
#            cgpa  resume_score      placed
# count  100.0000    100.000000  100.000000
# mean     6.9422      6.930500    0.500000
# std      1.1192      0.979608    0.502519
# min      5.2700      4.950000    0.000000
# 25%      5.9800      6.190000    0.000000
# 50%      6.6200      7.055000    0.500000
# 75%      8.0450      7.640000    1.000000
# max      9.4000      9.060000    1.000000

# %%
s = df.axes
s
# Out:
# [RangeIndex(start=0, stop=100, step=1),
#  Index(['cgpa', 'resume_score', 'placed'], dtype='str')]

# %%
p = df.dtypes
p
# Out:
# cgpa            float64
# resume_score    float64
# placed            int64
# dtype: object

# %%
b = df.empty # it return true if ther is any missing value in the dataset
b
# Out:
# False

# %%
df = df.dropna() # for check missing value

# %%
df.ndim # number of axex
# Out:
# 2

# %%
df.shape
# Out:
# (100, 3)

# %%
df.shape[0] # give the total number of rows in the data
df.shape[1]# give the total number of columns in the dataset
# Out:
# 3

# %%
df.size  # row count * col_Count
# Out:
# 300

# %%
df.values # get a numpy array for df values
# Out:
# array([[8.14, 6.52, 1.  ],
#        [6.17, 5.17, 0.  ],
#        [8.27, 8.86, 1.  ],
#        [6.88, 7.27, 1.  ],
#        [7.52, 7.3 , 1.  ],
#        [8.77, 6.19, 1.  ],
#        [5.34, 7.09, 0.  ],
#        [6.56, 6.29, 0.  ],
#        [6.32, 6.71, 0.  ],
#        [7.69, 7.12, 1.  ],
#        [6.18, 6.35, 0.  ],
#        [5.44, 6.54, 0.  ],
#        [6.09, 7.01, 0.  ],
#        [8.5 , 5.09, 1.  ],
#        [7.51, 6.25, 1.  ],
#        [8.88, 5.93, 1.  ],
#        [8.04, 7.64, 1.  ],
#        [7.81, 8.71, 1.  ],
#        [5.94, 5.88, 0.  ],
#        [6.75, 8.11, 1.  ],
#        [5.8 , 8.06, 0.  ],
#        [6.53, 7.64, 0.  ],
#        [6.16, 5.77, 0.  ],
#        [6.05, 7.13, 0.  ],
#        [8.22, 6.18, 1.  ],
#        [7.76, 5.68, 1.  ],
#        [6.27, 6.47, 0.  ],
#        [5.51, 6.15, 0.  ],
#        [7.46, 7.67, 1.  ],
#        [6.19, 7.3 , 0.  ],
#        [7.36, 7.15, 1.  ],
#        [5.92, 7.02, 0.  ],
#        [5.87, 7.96, 0.  ],
#        [8.43, 7.73, 1.  ],
# ...

# %%
df = df.copy()

# %%
p = df.sort_values(by = 'resume_score')
p
# Out:
#     cgpa  resume_score  placed
# 94  8.01          4.95       1
# 87  5.62          5.05       0
# 13  8.50          5.09       1
# 41  8.68          5.15       1
# 1   6.17          5.17       0
# ..   ...           ...     ...
# 17  7.81          8.71       1
# 38  6.00          8.72       0
# 65  6.04          8.75       0
# 2   8.27          8.86       1
# 69  8.06          9.06       1
#
# [100 rows x 3 columns]

# %%
# x =  df.astype(int) # type conversion
df['cgpa'] = df['cgpa'].astype(int)
df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
df['cgpa'] = df['cgpa'].astype(str)
df
# Out:
#    cgpa  resume_score  placed
# 0     8          6.52       1
# 1     6          5.17       0
# 2     8          8.86       1
# 3     6          7.27       1
# 4     7          7.30       1
# ..  ...           ...     ...
# 95    6          6.38       0
# 96    8          7.76       1
# 97    6          7.78       0
# 98    8          5.63       1
# 99    6          6.61       0
#
# [100 rows x 3 columns]

# %%
df.dtypes
# Out:
# cgpa                str
# resume_score    float64
# placed            int64
# dtype: object

# %%
df['cgpa'] = df['cgpa'].astype(int)
df
# Out:
#     cgpa  resume_score  placed
# 0      8          6.52       1
# 1      6          5.17       0
# 2      8          8.86       1
# 3      6          7.27       1
# 4      7          7.30       1
# ..   ...           ...     ...
# 95     6          6.38       0
# 96     8          7.76       1
# 97     6          7.78       0
# 98     8          5.63       1
# 99     6          6.61       0
#
# [100 rows x 3 columns]

# %%
df['cgpa'] = df['cgpa'].add(4)

# %%
s = df.count()
s
# Out:
# cgpa            100
# resume_score    100
# placed          100
# dtype: int64

# %%
df.max()
# Out:
# cgpa            13.00
# resume_score     9.06
# placed           1.00
# dtype: float64

# %%
df.min()
# Out:
# cgpa            9.00
# resume_score    4.95
# placed          0.00
# dtype: float64

# %%
g = df.filter(items = ['cgpa','placed'])
g
# Out:
#     cgpa  placed
# 0     12       1
# 1     10       0
# 2     12       1
# 3     10       1
# 4     11       1
# ..   ...     ...
# 95    10       0
# 96    12       1
# 97    10       0
# 98    12       1
# 99    10       0
#
# [100 rows x 2 columns]

# %%
df[['cgpa','placed']]
# Out:
#     cgpa  placed
# 0     12       1
# 1     10       0
# 2     12       1
# 3     10       1
# 4     11       1
# ..   ...     ...
# 95    10       0
# 96    12       1
# 97    10       0
# 98    12       1
# 99    10       0
#
# [100 rows x 2 columns]

# %%
df.filter(items = [5,6] ,axis = 0)  # axis  = 0 menas row wise operation
# Out:
#    cgpa  resume_score  placed
# 5    12          6.19       1
# 6     9          7.09       0

# %%
df.filter(like = '5', axis = 0)
# Out:
#     cgpa  resume_score  placed
# 5     12          6.19       1
# 15    12          5.93       1
# 25    11          5.68       1
# 35    12          7.48       1
# 45    12          5.44       1
# 50    12          6.74       1
# 51    10          7.39       0
# 52     9          7.50       0
# 53    10          7.16       0
# 54     9          7.18       0
# 55    10          6.87       1
# 56    10          6.43       0
# 57    10          7.21       0
# 58    10          7.37       0
# 59     9          7.57       0
# 65    10          8.75       0
# 75    10          7.94       1
# 85    10          5.46       0
# 95    10          6.38       0

# %%
s = df.to_dict()
s
# Out:
# {'cgpa': {0: 12,
#   1: 10,
#   2: 12,
#   3: 10,
#   4: 11,
#   5: 12,
#   6: 9,
#   7: 10,
#   8: 10,
#   9: 11,
#   10: 10,
#   11: 9,
#   12: 10,
#   13: 12,
#   14: 11,
#   15: 12,
#   16: 12,
#   17: 11,
#   18: 9,
#   19: 10,
#   20: 9,
#   21: 10,
#   22: 10,
#   23: 10,
#   24: 12,
#   25: 11,
#   26: 10,
#   27: 9,
#   28: 11,
#   29: 10,
#   30: 11,
#   31: 9,
#   32: 9,
#   33: 12,
#   34: 12,
#   35: 12,
#   36: 12,
#   37: 13,
#   38: 10,
#   39: 11,
#   40: 12,
#   41: 12,
#   42: 10,
#   43: 12,
#   44: 9,
#   45: 12,
#   46: 9,
#   47: 11,
#   48: 9,
#   49: 9,
#   50: 12,
#   51: 10,
#   52: 9,
#   53: 10,
#   54: 9,
#   55: 10,
#   56: 10,
#   57: 10,
#   58: 10,
#   59: 9,
#   60: 9,
#   61: 10,
#   62: 9,
#   63: 12,
#   64: 11,
#   65: 10,
#   66: 12,
#   67: 10,
#   68: 10,
#   69: 12,
#   70: 11,
#   71: 11,
#   72: 11,
#   73: 9,
#   74: 9,
#   75: 10,
#   76: 13,
#   77: 9,
#   78: 9,
#   79: 9,
#   80: 11,
#   81: 10,
#   82: 11,
#   83: 11,
#   84: 9,
# ...

# %%
df['half'] = df['cgpa'].where(df['cgpa'] > 7, other = 0)
df.head()
# Out:
#    cgpa  resume_score  placed  half
# 0    12          6.52       1    12
# 1    10          5.17       0    10
# 2    12          8.86       1    12
# 3    10          7.27       1    10
# 4    11          7.30       1    11
