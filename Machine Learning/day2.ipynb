# %%
# make a google form fill the enteries when you submit it that data will submit in sql db-
# after with the help of sql connector connect ----> after then apply feature engineering and then-
#------> apply model get the score

# %%
#
''' Linear Regression -> it is supervised machine learning  algorithm that is used to predict a 

continous numerical value based on one or more input features it finds a  straight line relationship 
between input and output
y = mx + b
where x and y are points m is slope is weightae how much y change when x change 
b -> if in any condition m or x become zero so the equation will become zero 
so b is a constant value vo us line ko bnye rkne mai contribution de rha hai
if anychange m or x become zero then b will become ezual to the constant value to vo us line ko bnye rakhega
so b is equal to the intercept , it is the value of y when x is equal to zero


when do we use linear regression?
we use linear regression when output is continous ex price , salary , sale amount
relation ship is linear 
when input and output follow a  straight line trend 
ex more exp  higher salary
ex more adds higher sales


when not to use linear regression
when data is non linear  when output is categorcial when there are so many outlier
when  relationship is complex


if data is not linear then which model to use
when data is cureved and stills follows a smmoth pattern then we will use polynomial regression
example:: house price increases fast after a certain area 
salary grows slowly then fast then stable still linear regression but with polynomial feature


what is overfitting ?
means model learn too much , model memorize training data that's why high training 
accuraccy but very low  test accuracy

example: u prepare only last year exam  questions and memorize them u score 
full marks in practice but fail in the real exam

what is underfitting?
means model learn too little that why low training accuracy and test accuracy

example:  u study only basic formula and skip practice 
then u fail both mock and final exam


why does overfitting happend:
when we have too many features , very complex model, small dataset, no regularization


what is regularization:
regularzation control the model complexity it panaleize large weights so the model stays simple

for this we add a penealty term to the loss function(diff between actual value and predicted value)


machine learning model lagya -> model overfit / underfit kar rha hai --->if overfit kr rha hai
then apan regularization lagyenge -> in regularization term mai agya   riz and lasso

what is  riz  and lasso ?  (these are the penalty term)

linear regreession tries to fit y = m1x1 +m2x2 ...+ b when we have so many columns in terms
so if feature are  many or data is noisy then we get overfitting and the coefficeint(m and b) become 
very large  

solution1 : 
Ridge Regression (also called L2 Regularization). 
The loss function is based on Mean Squared Error (MSE):

MSE=n1​i=1∑n​(yi​−y^​i​)2

(1/n )*(yi - y^​i)**2 

loss = 1/n * yi - hhead**2 ye formula hai loss ka mean square dir k respect mai


Model sirf error ko reduce karne ki koshish karta hai 
(error matlab prediction ko actual value ke close lana).

Lekin model sirf error ko kam karta hai, complexity ko control nahi karta. 
Is wajah se model overfit bhi ho sakta hai.

Ridge Regression error ke saath-saath model ki complexity ko bhi reduce karta hai.
Iske liye ye weights ke square ki penalty add karta hai.

Updated Loss = Purana Loss + Penalty Term
Loss = Error + Penalty

Error   = (1/n) * Σ(y - y_hat)^2
Penalty = λ * Σ(w^2)


# λ -> regularization stenght 
MSE → prediction error
w² → weights ka square
λ → penalty ki strength control karta hai.


what actually happens
large weights ---> m ko bol rhe hai  , increase loss so model is fortunate to keep weight small
so no coeffiecent become zero

training process:
during gradinet decent:(this is the approch to minimize the loss function) 

this gradinet decent during the training process error tries to reduce the loss
and panelty tries to shrink the weights which means final weights will be our balanced solution

for prediction y = m1x1 + m2x2 +b but weights are stable and small
that why it will return better generazlization 


when to use Ridze ?
when we want many correlated fetures (ek columsn k badne or gatne se dusre columns p effect pade)
and all feature are use full and we want stable model 


how lasso regression works?
we know that equation of simple line y = mx +b
lasso add absolute weights 


Updated Loss = Purana Loss + Penalty Term(lembda)

Error   = (1/n) * Σ(y - y_hat)%2


How Lasso Regression Works?

We know the equation of a simple line:

y = mx + b

Model pehle sirf error ko reduce karta hai.

Error = (1/n) * Σ(y - y_hat)^2

Lasso Regression error ke saath ek penalty term add karta hai.

Updated Loss = Purana Loss + Penalty Term

Loss = (1/n) * Σ(y - y_hat)^2 + λ * Σ|w|

Yahan:

|w| = absolute value of weights
λ = regularization parameter

Ridge Regression -> λ * Σ(w²)
Lasso Regression -> λ * Σ|w|

Important point:

Ridge -> weights ko chhota karta hai.
Lasso -> kuch weights ko exactly 0 kar sakta hai.

Isliye Lasso feature selection bhi karta hai.

Ye line exam/interview me bahut kaam aati hai:

Lasso Regression adds the absolute value of weights (L1 penalty),
which can shrink some weights to zero and automatically remove less important features.



what happens when we use lasso?
panelty increase linearly 
some weights are pushed to excatly to zero  model automatically remove feature(irrelvent feature)

during the training process gradient decent shrinks weights 
actual =  y_pred - y_test  isko miminze krta hai gradient decent

then weak feature weight become zero and strong feature survives

when to use lasso?
when we have to many features , and feature selection needed and we want simpler model


how linear regression model works ?
1.we know that simple line y = mx +b 
then it make inital prediction it will start with random weights (
example lets say we have too many feature , say we have a box and in that there are many balls
balls are feature , if i pick one ball it will have some weight , in physics 
we know that every things that exis in universe contains some weight e = mc **2
so agar uska weight hoga to vo usko randomly pcik krega), then it will predict output values

so these prediction will be wrong initally
if prediction jada aya ya kam aya to measure this it will use loss function 
(diff bet actual and predicted)

then it will measure how wrong prediction are lower loss = better model performance

then it will use optimization(gradient decent) for update the weights to minimize the loss
then we will find model performance


note:
lasso : ye penelty mai add kr rha hai mod of weight isse kya benfit hoga  jo irrelevant feature honge
means internally ye kya krega dataframe dot(.) correlation -> aur jo co-relation ki value hai
vo 3 tarkie se ati hai +1,-1,and 0 
+1 -> ek feature k badne se dusra feature bhi bad rha hai
-1 -> ek feature k gatne se dusra feature bhi ghat rha hai
0 -> ek feature k badne or gatne se dusra feature k upar koi farak nhi pad rha 

so is tarike se correation nikalge fir jo irrelevant features honge  ye unke weights ko zero kar dega

so apne data k pass relevent feature bache so ab relevent feature banege to model unke bich mai relation
samaj payega if relation samaj payega to model better genearlization kr payega agar better
generalization kr payega to model k performance achi ayegi

loss value  = actual value -predicted value
gradinet decent =  -> optimization techinquer jo apka prediction hai vo actual k close jana chiye
means y_test k jaa rha rha hai y_pred so y_test - y_pred ka jo result a rha hai vo tends to zero so iska
jo difference hai zero k close jaa rh hai proper zero means actual prediction ban gya

gradinet decent
stocastinc gradient decent
mini batch gradinet decent
'''
# Out:
# ' Linear Regression -> it is supervised machine learning  algorithm that is used to predict a \n\ncontinous numerical value based on one or more input features it finds a  straight line relationship \nbetween input and output\ny = mx + b\nwhere x and y are points m is slope is weightae how much y change when x change \n'
