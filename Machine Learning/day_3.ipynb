# %% [markdown]
# # Dont Run THis on your local system program will crash run only on Collab

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('/content/insurance - insurance.csv')

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()

# %%
x = df.drop(columns = 'charges')
y = df['charges']

# %%
cat = df.select_dtypes(include='object').columns

# %%
for i in cat:
    x[i] = lb.fit_transform(x[i])

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7833463107364539

# %%
from sklearn.linear_model import Ridge , Lasso

# %%
#Ridge Regression Model
ridgeReg = Ridge(alpha=10)  # penealtyh term lembda  we can tune this

ridgeReg.fit(x_train,y_train)

#train and test scorefor ridge regression
train_score_ridge = ridgeReg.score(x_train, y_train)
test_score_ridge = ridgeReg.score(x_test, y_test)

# %%
print("\nRidge Model............................................\n")
print("The train score for ridge model is {}".format(train_score_ridge))
print("The test score for ridge model is {}".format(test_score_ridge))
# Out:
# Ridge Model............................................
#
# The train score for ridge model is 0.7398386827259329
# The test score for ridge model is 0.7793155691007558

# %%
#Lasso regression model
print("\nLasso Model............................................\n")
lasso = Lasso(alpha = 10)
lasso.fit(x_train,y_train)
train_score_ls =lasso.score(x_train,y_train)
test_score_ls =lasso.score(x_test,y_test)

print("The train score for ls model is {}".format(train_score_ls))
print("The test score for ls model is {}".format(test_score_ls))
# Out:
# Lasso Model............................................
#
# The train score for ls model is 0.7416990458357842
# The test score for ls model is 0.7831229831162652

# %%
# Polynomial Regression
from sklearn.preprocessing import PolynomialFeatures

# %%
poly = PolynomialFeatures(degree = 4)
x_poly = poly.fit_transform(x_train)
poly.fit(x_poly,y_train)
# Out:
# PolynomialFeatures(degree=4)

# %%
lin2 = LinearRegression()
lin2.fit(x_poly,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lin2.predict(poly.fit_transform(x_test))
r2_score(y_test,y_pred)
# Out:
# 0.7717529958521865

# %%
# data --- > x,y
# x ---. binomial feature show in visualization
# x ---- > polynomial regression
# y --- > no change
# linear_regression.fit(x_poly,y)
# y_pred
# r2_score(y_test , y_pred)
