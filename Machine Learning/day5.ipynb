# %%
# Decision Tree

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\PIYUSH\OneDrive\Desktop\Data-Science\Datasets\insurance - insurance.csv')

# %%
df.head(3)
# Out:
#    age     sex    bmi  children smoker     region     charges
# 0   19  female  27.90         0    yes  southwest  16884.9240
# 1   18    male  33.77         1     no  southeast   1725.5523
# 2   28    male  33.00         3     no  southeast   4449.4620

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
x = df.drop(columns = 'charges')
y  = df['charges']

# %%
cat  = x.select_dtypes(include = 'object')
# Out:
# C:\Users\PIYUSH\AppData\Local\Temp\ipykernel_17800\2675790427.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat  = x.select_dtypes(include = 'object')

# %%
lb = LabelEncoder()

# %%
for i in cat:
    x[i] = lb.fit_transform(x[i])

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.2,random_state = 42)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt = DecisionTreeRegressor()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = dt.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7163354956664136

# %%
df2 = pd.read_csv(r'C:\Users\PIYUSH\OneDrive\Desktop\Data-Science\Datasets\covid_toy - covid_toy.csv')

# %%
df2.head(2)
# Out:
#    age gender  fever cough     city has_covid
# 0   60   Male  103.0  Mild  Kolkata        No
# 1   27   Male  100.0  Mild    Delhi       Yes

# %%
df2.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
df2['fever'] = df2['fever'].fillna(df2['fever'].mean())

# %%
x = df2.drop(columns = 'has_covid')
y = df2['has_covid']

# %%
cat = df2.select_dtypes(include = 'object').columns
# Out:
# C:\Users\PIYUSH\AppData\Local\Temp\ipykernel_17800\3238301885.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat = df2.select_dtypes(include = 'object').columns

# %%
x
# Out:
#     age  gender  fever  cough  city
# 0    60       1  103.0      0     2
# 1    27       1  100.0      0     1
# 2    42       1  101.0      0     1
# 3    31       0   98.0      0     2
# 4    65       0  101.0      0     3
# ..  ...     ...    ...    ...   ...
# 95   12       0  104.0      0     0
# 96   51       0  101.0      1     2
# 97   20       0  101.0      0     0
# 98    5       0   98.0      1     3
# 99   10       0   98.0      1     2
#
# [100 rows x 5 columns]

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.2,random_state=42)

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dtc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.4
